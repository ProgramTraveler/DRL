# %% [markdown]
# <a href="https://www.kaggle.com/code/chhelp/unit-7-let-s-train-our-soccer-team?scriptVersionId=143839983" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # noting about code in the Unit
